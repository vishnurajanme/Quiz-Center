# %% [markdown]
# <a href="https://colab.research.google.com/github/vishnurajanme/Quiz-Center/blob/master/quizcenter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Step1: Install Chart Studio
# !pip install chart_studio
# Out:
# ...
#      |████████████████████████████████| 71kB 2.5MB/s
# ...

# %%
#A piece of code to combine all quiz scoresheets to 1
#Generate a 2nd scoresheet with the difference of old data and new data
#coded by vishnu rajan
#Authenticating its me :P
from google.colab import auth
auth.authenticate_user()
import gspread
from oauth2client.client import GoogleCredentials
gc = gspread.authorize(GoogleCredentials.get_application_default())
import re
import pandas
import pandas as pd
import re
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import chart_studio
username = 'vishnurajanme'
api_key ='xxx'
chart_studio.tools.set_credentials_file(username, api_key)
import chart_studio.plotly as py
import chart_studio.tools as tls
import matplotlib.pyplot as plt
import pytz
tz = pytz.timezone('Asia/Calcutta')
from datetime import datetime as dt
#write function
def iter_pd(df):
    for val in df.columns:
        yield val
    for row in df.to_numpy():
        for val in row:
            if pd.isna(val):
                yield ""
            else:
                yield val
def pandas_to_sheets(pandas_df, sheet, clear = True):
    # Updates all values in a workbook to match a pandas dataframe
    if clear:
        sheet.clear()
    (row, col) = pandas_df.shape
    cells = sheet.range("A1:{}".format(gspread.utils.rowcol_to_a1(row + 1, col)))
    for cell, val in zip(cells, iter_pd(pandas_df)):
        cell.value = val
    sheet.update_cells(cells)
#opening the combo sheet for writing
directout = gc.open_by_url('https://docs.google.com/spreadsheets/d/xxx')
combined = directout.sheet1
directout1 = gc.open_by_url('https://docs.google.com/spreadsheets/d/xxx')
nosahrdaya = directout1.sheet1
directout2 = gc.open_by_url('https://docs.google.com/spreadsheets/d/xxx')
dupli = directout2.sheet1
search = gc.open_by_url('https://docs.google.com/spreadsheets/d/xxx')
ser = search.sheet1

#Website statistics updation
statistics = gc.open_by_url('https://docs.google.com/spreadsheets/d/xxx')
stati = statistics.sheet1

ssstat = gc.open_by_url('https://docs.google.com/spreadsheets/d/xxx').sheet1.get_all_values()#BME01
sstat = pd.DataFrame.from_records(ssstat[1:],columns=ssstat[0])

#reading existing sheets
ss1 = gc.open_by_url('https://docs.google.com/spreadsheets/d/1xkd-xxx').sheet1.get_all_values()#ECEQ1
ss2 = gc.open_by_url('https://docs.google.com/spreadsheets/d/xxx').sheet1.get_all_values()#BTEQ1
ss3 = gc.open_by_url('https://docs.google.com/spreadsheets/d/xxx').sheet1.get_all_values()#coronaV2
ss4 = gc.open_by_url('https://docs.google.com/spreadsheets/d/13T-xxx-xx').sheet1.get_all_values()#coronaV1
ss5 = gc.open_by_url('https://docs.google.com/spreadsheets/d/xxx').sheet1.get_all_values()#forensics
ss6 = gc.open_by_url('https://docs.google.com/spreadsheets/d/xxx-o').sheet1.get_all_values()#ECEtop
ss7 = gc.open_by_url('https://docs.google.com/spreadsheets/d/1Un5l-xxx').sheet1.get_all_values()#CSEQ1
ss8 = gc.open_by_url('https://docs.google.com/spreadsheets/d/xx-xx').sheet1.get_all_values()#BME01
ss9 = gc.open_by_url('https://docs.google.com/spreadsheets/d/xx-xx').sheet1.get_all_values()#CHEM1
ss10 = gc.open_by_url('https://docs.google.com/spreadsheets/d/xx').sheet1.get_all_values()#MATH1
ss11 = gc.open_by_url('https://docs.google.com/spreadsheets/d/xx').sheet1.get_all_values()#PHY1




#converting to pandas df
s1 = pd.DataFrame.from_records(ss1[1:],columns=ss1[0])
s2 = pd.DataFrame.from_records(ss2[1:],columns=ss2[0])
s3 = pd.DataFrame.from_records(ss3[1:],columns=ss3[0])
s4 = pd.DataFrame.from_records(ss4[1:],columns=ss4[0])
s5 = pd.DataFrame.from_records(ss5[1:],columns=ss5[0])
s6 = pd.DataFrame.from_records(ss6[1:],columns=ss6[0])
s7 = pd.DataFrame.from_records(ss7[1:],columns=ss7[0])
s8 = pd.DataFrame.from_records(ss8[1:],columns=ss8[0])
s9 = pd.DataFrame.from_records(ss9[1:],columns=ss9[0])
s10 = pd.DataFrame.from_records(ss10[1:],columns=ss10[0])
s11 = pd.DataFrame.from_records(ss11[1:],columns=ss11[0])


#extracting needed information alone
ece = s1[['Email Address','Full Name','Institution', 'Class/Branch of Study', 'Mobile Number', 'Score']].copy()
ece.columns = ['Email','Name','Institution', 'Class', 'Mobile', 'Score']
ece['Course'] = 'Basics of Electronics'
bte = s2[['Email Address','Full Name','Institution', 'Class/Branch of Study', 'Mobile Number', 'Score']].copy()
bte.columns = ['Email','Name','Institution', 'Class', 'Mobile', 'Score']
bte['Course'] = 'Basics of Biotechnology'
cor = s3[['Email Address','Full Name','Organisation/Institution', 'Class/Branch of study', 'Mobile Number', 'Score']].copy()
cor.columns = ['Email','Name','Institution', 'Class', 'Mobile', 'Score']
cor['Course'] = 'Kerala corona quiz V2.0'

old = s4[['Email','Name','Institution', 'Class', 'Mobile']].copy()
old['Course'] = 'Kerala corona quiz V1.0'


fore = s5[['Email Address','Full Name','Institution', 'Class/Branch of Study', 'Mobile Number', 'Score']].copy()
fore.columns = ['Email','Name','Institution', 'Class', 'Mobile', 'Score']
fore['Course'] = 'Basics of Forensics'

cse = s7[['Email Address','Full Name','Institution', 'Class/Branch of Study', 'Mobile Number', 'Score']].copy()
cse.columns = ['Email','Name','Institution', 'Class', 'Mobile', 'Score']
cse['Course'] = 'Basics of Computer Science'

bme = s8[['Email Address','Full Name','Institution', 'Class/Branch of Study', 'Mobile Number', 'Score']].copy()
bme.columns = ['Email','Name','Institution', 'Class', 'Mobile', 'Score']
bme['Course'] = 'Basics of Biomedical Equipments'

ecec = s6[['Email Address','Full Name','Institution', 'Verdict', 'Total', 'Score']].copy()
ecec.columns = ['Email','Name','Institution', 'Class', 'Mobile', 'Score']
ecec['Course'] = 'Quiz Series on Basics of ECE (10 Quizzes)'

chem1 = s9[['Email Address','Full Name','Institution', 'Class/Branch of Study', 'Mobile Number', 'Score']].copy()
chem1.columns = ['Email','Name','Institution', 'Class', 'Mobile', 'Score']
chem1['Course'] = 'Basics of Chemistry'

math1 = s10[['Email Address','Full Name','Institution', 'Class/Branch of Study', 'Mobile Number', 'Score']].copy()
math1.columns = ['Email','Name','Institution', 'Class', 'Mobile', 'Score']
math1['Course'] = 'Basics of Mathematics'

phy1 = s11[['Email Address','Full Name','Institution', 'Class/Branch of Study', 'Mobile Number', 'Score']].copy()
phy1.columns = ['Email','Name','Institution', 'Class', 'Mobile', 'Score']
phy1['Course'] = 'Basics of Physics'

#datafusion
duplicated = pd.concat([ece,bte,cor,old,fore,cse,bme,ecec,chem1,math1,phy1]).reset_index(drop=True)
pandas_to_sheets(duplicated, dupli)

searchdata = duplicated[['Email','Name','Institution','Course']].copy()
pandas_to_sheets(searchdata, ser)

fulldata  = pd.concat([ece,bte,cor,old,fore,cse,bme,ecec,chem1,math1,phy1]).drop_duplicates().reset_index(drop=True)
fulldata1  = pd.concat([ece,bte,fore,cse,bme,ecec,chem1,math1,phy1]).drop_duplicates().reset_index(drop=True)
pandas_to_sheets(fulldata, combined)
searchfor = ['Sahrdaya', 'sahrdaya', 'SAHRDAYA', 'SCET', 'Scet', 'scet']
new = fulldata[~fulldata.Institution.str.contains('|'.join(searchfor))]
pandas_to_sheets(new, nosahrdaya)
d = duplicated.duplicated(subset=['Email'], keep='first')

maxx = new.groupby(['Name', 'Institution']).size().reset_index(name='count').sort_values(['count'], ascending=[False])
maxx = maxx[1:8]

alll = fulldata.groupby(['Name', 'Institution']).size().reset_index(name='count').sort_values(['count'], ascending=[False])
alll = alll[1:100]

toppers = fulldata1[['Name', 'Institution', 'Course', 'Score']].sort_values(['Score'], ascending=[False])
toppers = toppers[1:100]

top = s6.sort_values(['Total'], ascending=[False]).reset_index(drop=True)
top = top[0:1]


full = duplicated.shape[0]
full_nodupli = fulldata.shape[0]
shr = new.shape[0]
dupli = duplicated[~d].shape[0]
print("Last updated on {}".format(dt.now(tz)) )


## Statistics for our website new data
statnew = [[str(full),str(shr),str(full-shr),str(dupli)]] 
statnew = pd.DataFrame(statnew, columns = ["Total No. of Students<br>who cracked the quizzes", "Students from<br>Sahrdaya College",
      "Students from <br>Other Institutions", "Students who did <br>more than 1 quiz"]) 

#Graph creation

config = {'displayModeBar': False}

figs1 = go.Figure()
figs1.add_trace(go.Indicator(
    mode = "number+delta",
    value = int(statnew['Total No. of Students<br>who cracked the quizzes'][0]),
    title = {"text": "Total No. of Students<br>Who Completed Quizzes<span style='font-size:0.8em;color:gray'>"},
    domain = {'x': [0, 1], 'y': [0, 1]},
    delta = {'reference': int(sstat['Total No. of Students<br>who cracked the quizzes'][0]), 'relative': True}))
figs1.update_layout(
    autosize=True,
    margin=go.layout.Margin(
        l=0, #left margin
        r=0, #right margin
        b=0, #bottom margin
        t=30  #top margin
        ))
figs1.show(config=config)

figs2 = go.Figure()
figs2.add_trace(go.Indicator(
    mode = "number+delta",
    value = int(statnew['Students from<br>Sahrdaya College'][0]),
    title = {"text": "Students from <br>Other Institutions<span style='font-size:0.8em;color:gray'>"},
    domain = {'x': [0, 1], 'y': [0, 1]},
    delta = {'reference': int(sstat['Students from<br>Sahrdaya College'][0]), 'relative': True}))
figs2.update_layout(
    autosize=True,
    margin=go.layout.Margin(
        l=0, #left margin
        r=0, #right margin
        b=0, #bottom margin
        t=30  #top margin
        ))
figs2.show(config=config)

figs3 = go.Figure()
figs3.add_trace(go.Indicator(
    mode = "number+delta",
    value = int(statnew['Students from <br>Other Institutions'][0]),
    title = {"text": "Students from<br>Sahrdaya College<span style='font-size:0.8em;color:gray'>"},
    domain = {'x': [0, 1], 'y': [0, 1]},
    delta = {'reference': int(sstat['Students from <br>Other Institutions'][0]), 'relative': True}))
figs3.update_layout(
    autosize=True,
    margin=go.layout.Margin(
        l=0, #left margin
        r=0, #right margin
        b=0, #bottom margin
        t=30  #top margin
        ))
figs3.show(config=config)

figs4 = go.Figure()
figs4.add_trace(go.Indicator(
    mode = "number+delta",
    value = int(statnew['Students who did <br>more than 1 quiz'][0]),
    title = {"text": "Students who did <br>more than 1 quiz<span style='font-size:0.8em;color:gray'>"},
    domain = {'x': [0, 1], 'y': [0, 1]},
    delta = {'reference': int(sstat['Students who did <br>more than 1 quiz'][0]), 'relative': True}))
figs4.update_layout(
    autosize=True,
    margin=go.layout.Margin(
        l=0, #left margin
        r=0, #right margin
        b=0, #bottom margin
        t=30  #top margin
        ))
figs4.show(config=config)

figs5 = go.Figure()
figs5.add_trace(go.Indicator(
    mode = "number",
    value = int(top['Total'][0]),
    title = {"text": "ECE Quiz Top Scorer<br><span style='font-size:1em;color:#2B814B'>" + (top['Full Name'][0]) + "</span><br>SCORE:"},
    domain = {'x': [0, 1], 'y': [0, 1]}))
figs5.update_layout(
    autosize=True,
    margin=go.layout.Margin(
        l=0, #left margin
        r=0, #right margin
        b=0, #bottom margin
        t=50  #top margin
        ))
figs5.show(config=config)


figl = go.Figure(data=[go.Table(header=dict(line_color='white',
    fill_color='white',
    align=['center'],
    font=dict(color='#2B814B', size=25),
    height=30, values= ['Name', 'Institution', 'Count']),
                 cells=dict(line_color='white',
    fill_color='white',
    align=['center'],
    font=dict(color='#435067', size=12),
    height=30, values= [alll['Name'], alll['Institution'], alll['count']]))
                     ])
figl.update_layout(
    autosize=True,
    margin=go.layout.Margin(
        l=0, #left margin
        r=0, #right margin
        b=0, #bottom margin
        t=10  #top margin
        ))
figl.show(config=config)

figl1 = go.Figure(data=[go.Table(header=dict(line_color='white',
    fill_color='white',
    align=['center'],
    font=dict(color='#2B814B', size=25),
    height=30, values= ['Name', 'Institution', 'Course', 'Score']),
                 cells=dict(line_color='white',
    fill_color='white',
    align=['center'],
    font=dict(color='#435067', size=12),
    height=30, values= [toppers['Name'], toppers['Institution'], toppers['Course'], toppers['Score']]))
                     ])
figl1.update_layout(
    autosize=True,
    margin=go.layout.Margin(
        l=0, #left margin
        r=0, #right margin
        b=0, #bottom margin
        t=10  #top margin
        ))
figl1.show(config=config)
# Out:
# Last updated on 2020-06-10 12:08:02.546265+05:30
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="930865ef-bdb2-438c-a21b-6acbb8681c94" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("930865ef-bdb2-438c-a21b-6acbb8681c94")) {
#                     Plotly.newPlot(
#                         '930865ef-bdb2-438c-a21b-6acbb8681c94',
# ...

# %%
py.plot(figs1, filename = 'sitestatistics1', output_type='div', show_link=False, auto_open = False, config=dict(displayModeBar=False))
py.plot(figs2, filename = 'sitestatistics2', output_type='div', show_link=False, auto_open = False, config=dict(displayModeBar=False))
py.plot(figs3, filename = 'sitestatistics3', output_type='div', show_link=False, auto_open = False, config=dict(displayModeBar=False))
py.plot(figs4, filename = 'sitestatistics4', output_type='div', show_link=False, auto_open = False, config=dict(displayModeBar=False))
py.plot(figs5, filename = 'sitestatistics5', output_type='div', show_link=False, auto_open = False, config=dict(displayModeBar=False))
py.plot(figl, filename = 'leaderboard', output_type='div', show_link=False, auto_open = False, config=dict(displayModeBar=False))
py.plot(figl1, filename = 'scoreboard', output_type='div', show_link=False, auto_open = False, config=dict(displayModeBar=False))
pandas_to_sheets(statnew, stati)
